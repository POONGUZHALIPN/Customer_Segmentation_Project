# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
df = pd.read_csv("Mall_Customers.csv")
X = df[['Age', 'Annual_Income']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
kmeans = KMeans(n_clusters=5,random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)
plt.figure(figsize=(10,6))
plt.scatter(df['Age'],df['Annual_Income'],c=df['Cluster'],s=70,alpha=0.7)
centers = scaler.inverse_transform(kmeans.cluster_centers_)
plt.scatter(centers[:,0],centers[:,1],s=300,c='red',marker='X',label='Centroids')

plt.xlabel("Age")
plt.ylabel("Annual Income")
plt.title("Customer Segmentation using K-Means")
plt.legend()
plt.show()
print("\nCluster Analysis:\n")
print(df.groupby('Cluster')[['Age', 'Annual_Income']].mean())
# Out:
# C:\Users\MATHI\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Analysis:
#
#                Age  Annual_Income
# Cluster
# 0        58.775000      44.025000
# 1        27.692308      72.403846
# 2        27.511628      29.697674
# 3        35.650000     109.300000
# 4        46.288889      69.400000
